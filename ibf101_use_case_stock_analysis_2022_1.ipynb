# %% [markdown]
# <a href="https://colab.research.google.com/github/alexhungtraining/LUFT2024/blob/main/ibf101_use_case_stock_analysis_2022_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Demo on using data from Yahoo Finance for stock analysis </h1>

# %% [markdown]
# Python has been gaining significant traction in the financial industry.
# Some experienced quantitative traders are using Python to develop and backtest a quantitative trading strategy
# How to use Pandas to call a Finance API for stock data and easily calculate moving averages and other analysis
#
# In the notebook, I am sharing the way to use Python Numpy, Pandas and Matplotlib to conduct some analysis.

# %% [markdown]
# <b> Importing the library required </b>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import datetime
#!pip install yfinance
# !python -m pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.48)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)

# %% [markdown]
# <b> Getting the data </b>
#
# <b> Pulling ths historial data with Yahoo API </b>

# %%
import yfinance as yf #stock

#start = datetime.datetime(2015,1,1)
#end = datetime.datetime(2020,12,25)

start = '2020-01-01'
end = '2023-01-07'
AAPL = yf.download("AAPL", start,end)
BABA = yf.download("BABA", start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.876106   75.087502   75.150002   73.797501
# 2020-01-03 00:00:00+00:00   72.167595   74.357498   75.144997   74.125000
# 2020-01-06 00:00:00+00:00   72.742653   74.949997   74.989998   73.187500
# 2020-01-07 00:00:00+00:00   72.400551   74.597504   75.224998   74.370003
# 2020-01-08 00:00:00+00:00   73.565201   75.797501   76.110001   74.290001
# ...                               ...         ...         ...         ...
# 2022-12-30 00:00:00+00:00  128.719330  129.929993  129.949997  127.430000
# 2023-01-03 00:00:00+00:00  123.904617  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.182610  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.855087  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.412231  129.619995  130.289993  124.889999
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00   74.059998  135480400
# 2020-01-03 00:00:00+00:00   74.287498  146322800
# 2020-01-06 00:00:00+00:00   73.447502  118387200
# 2020-01-07 00:00:00+00:00   74.959999  108872000
# 2020-01-08 00:00:00+00:00   74.290001  132079200
# ...                               ...        ...
# 2022-12-30 00:00:00+00:00  128.410004   77034200
# 2023-01-03 00:00:00+00:00  130.279999  112117500
# 2023-01-04 00:00:00+00:00  126.889999   89113600
# 2023-01-05 00:00:00+00:00  127.129997   80962700
# 2023-01-06 00:00:00+00:00  126.010002   87754700
#
# [760 rows x 6 columns]

# %%
type(AAPL)
# Out:
# pandas.core.frame.DataFrame

# %%
AAPL = yf.download("AAPL", start,end)
BABA = yf.download("BABA", start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
type(AAPL)
# Out:
# pandas.core.frame.DataFrame

# %%
AAPL.head(5)
# Out:
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  72.876106  75.087502  75.150002  73.797501
# 2020-01-03 00:00:00+00:00  72.167595  74.357498  75.144997  74.125000
# 2020-01-06 00:00:00+00:00  72.742653  74.949997  74.989998  73.187500
# 2020-01-07 00:00:00+00:00  72.400551  74.597504  75.224998  74.370003
# 2020-01-08 00:00:00+00:00  73.565201  75.797501  76.110001  74.290001
#
# Price                           Open     Volume
# Ticker                          AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  74.059998  135480400
# 2020-01-03 00:00:00+00:00  74.287498  146322800
# 2020-01-06 00:00:00+00:00  73.447502  118387200
# 2020-01-07 00:00:00+00:00  74.959999  108872000
# 2020-01-08 00:00:00+00:00  74.290001  132079200

# %%
AAPL.tail(5)
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2022-12-30 00:00:00+00:00  128.719330  129.929993  129.949997  127.430000
# 2023-01-03 00:00:00+00:00  123.904617  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.182610  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.855087  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.412231  129.619995  130.289993  124.889999
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2022-12-30 00:00:00+00:00  128.410004   77034200
# 2023-01-03 00:00:00+00:00  130.279999  112117500
# 2023-01-04 00:00:00+00:00  126.889999   89113600
# 2023-01-05 00:00:00+00:00  127.129997   80962700
# 2023-01-06 00:00:00+00:00  126.010002   87754700

# %%
BABA.head(5)
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           BABA        BABA        BABA        BABA
# Date
# 2020-01-02 00:00:00+00:00  212.242126  219.770004  219.979996  216.539993
# 2020-01-03 00:00:00+00:00  209.567017  217.000000  218.203003  216.009995
# 2020-01-06 00:00:00+00:00  209.219345  216.639999  217.160004  214.089996
# 2020-01-07 00:00:00+00:00  210.175446  217.630005  218.940002  216.690002
# 2020-01-08 00:00:00+00:00  210.532761  218.000000  220.649994  216.320007
#
# Price                            Open    Volume
# Ticker                           BABA      BABA
# Date
# 2020-01-02 00:00:00+00:00  216.600006  15873500
# 2020-01-03 00:00:00+00:00  216.350006   8604500
# 2020-01-06 00:00:00+00:00  214.889999  11885500
# 2020-01-07 00:00:00+00:00  217.639999   9388000
# 2020-01-08 00:00:00+00:00  216.600006  11959100

# %%
BABA.tail(5)
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           BABA        BABA        BABA        BABA
# Date
# 2022-12-30 00:00:00+00:00   85.072617   88.089996   89.410004   87.410004
# 2023-01-03 00:00:00+00:00   88.829376   91.980003   94.449997   90.750000
# 2023-01-04 00:00:00+00:00  100.360390  103.919998  104.519997   96.970001
# 2023-01-05 00:00:00+00:00  100.997787  104.580002  105.699997  100.639999
# 2023-01-06 00:00:00+00:00  103.721191  107.400002  108.000000  102.459999
#
# Price                            Open    Volume
# Ticker                           BABA      BABA
# Date
# 2022-12-30 00:00:00+00:00   87.449997  11926700
# 2023-01-03 00:00:00+00:00   91.110001  27891000
# 2023-01-04 00:00:00+00:00   98.849998  53291800
# 2023-01-05 00:00:00+00:00  101.400002  30400400
# 2023-01-06 00:00:00+00:00  104.110001  21072400

# %%
SP500 = yf.download("^SP500TR", start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
indexvar1
# Out:
# Price                        Adj Close        Close         High          Low  \
# Ticker                        ^SP500TR     ^SP500TR     ^SP500TR     ^SP500TR
# Date
# 2020-01-02 00:00:00+00:00  6609.290039  6609.290039  6609.669922  6564.020020
# 2020-01-03 00:00:00+00:00  6563.319824  6563.319824  6586.250000  6538.169922
# 2020-01-06 00:00:00+00:00  6586.540039  6586.540039  6587.310059  6522.339844
# 2020-01-07 00:00:00+00:00  6568.740234  6568.740234  6584.359863  6559.189941
# 2020-01-08 00:00:00+00:00  6601.149902  6601.149902  6629.609863  6568.160156
# ...                                ...          ...          ...          ...
# 2022-12-30 00:00:00+00:00  8178.020020  8178.020020  8178.430176  8094.620117
# 2023-01-03 00:00:00+00:00  8145.600098  8145.600098  8260.150391  8082.330078
# 2023-01-04 00:00:00+00:00  8207.419922  8207.419922  8249.830078  8129.629883
# 2023-01-05 00:00:00+00:00  8113.149902  8113.149902  8180.540039  8101.109863
# 2023-01-06 00:00:00+00:00  8298.610352  8298.610352  8322.290039  8117.020020
#
# Price                             Open   Volume
# Ticker                        ^SP500TR ^SP500TR
# Date
# 2020-01-02 00:00:00+00:00  6582.549805        0
# 2020-01-03 00:00:00+00:00  6546.089844        0
# 2020-01-06 00:00:00+00:00  6528.240234        0
# 2020-01-07 00:00:00+00:00  6578.229980        0
# 2020-01-08 00:00:00+00:00  6571.819824        0
# ...                                ...      ...
# 2022-12-30 00:00:00+00:00  8155.799805        0
# 2023-01-03 00:00:00+00:00  8207.690430        0
# 2023-01-04 00:00:00+00:00  8180.569824        0
# 2023-01-05 00:00:00+00:00  8180.540039        0
# 2023-01-06 00:00:00+00:00  8145.839844        0
#
# [760 rows x 6 columns]

# %%
SP500.to_csv('SP500.csv') # save to csv file

# %% [markdown]
# # 新段落

# %% [markdown]
# <b> Initial Plot using the plot() function </b>

# %%
AAPL.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.876106   75.087502   75.150002   73.797501
# 2020-01-03 00:00:00+00:00   72.167595   74.357498   75.144997   74.125000
# 2020-01-06 00:00:00+00:00   72.742653   74.949997   74.989998   73.187500
# 2020-01-07 00:00:00+00:00   72.400551   74.597504   75.224998   74.370003
# 2020-01-08 00:00:00+00:00   73.565201   75.797501   76.110001   74.290001
# ...                               ...         ...         ...         ...
# 2022-12-30 00:00:00+00:00  128.719330  129.929993  129.949997  127.430000
# 2023-01-03 00:00:00+00:00  123.904617  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.182610  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.855087  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.412231  129.619995  130.289993  124.889999
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00   74.059998  135480400
# 2020-01-03 00:00:00+00:00   74.287498  146322800
# 2020-01-06 00:00:00+00:00   73.447502  118387200
# 2020-01-07 00:00:00+00:00   74.959999  108872000
# 2020-01-08 00:00:00+00:00   74.290001  132079200
# ...                               ...        ...
# 2022-12-30 00:00:00+00:00  128.410004   77034200
# 2023-01-03 00:00:00+00:00  130.279999  112117500
# 2023-01-04 00:00:00+00:00  126.889999   89113600
# 2023-01-05 00:00:00+00:00  127.129997   80962700
# 2023-01-06 00:00:00+00:00  126.010002   87754700
#
# [760 rows x 6 columns]

# %%
AAPL['Adj Close']
# Out:
# Ticker                           AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.876106
# 2020-01-03 00:00:00+00:00   72.167595
# 2020-01-06 00:00:00+00:00   72.742653
# 2020-01-07 00:00:00+00:00   72.400551
# 2020-01-08 00:00:00+00:00   73.565201
# ...                               ...
# 2022-12-30 00:00:00+00:00  128.719330
# 2023-01-03 00:00:00+00:00  123.904617
# 2023-01-04 00:00:00+00:00  125.182610
# 2023-01-05 00:00:00+00:00  123.855087
# 2023-01-06 00:00:00+00:00  128.412231
#
# [760 rows x 1 columns]

# %%
AAPL['Adj Close'].plot(label = 'Apple', figsize = (8,4))
#BABA['Adj Close'].plot(label = 'Alibaba')
plt.xlabel("tran date")
plt.ylabel("$ adjusted close price")
plt.title ("Apple Stock price 1/1/2020 - 06/01/2023")
plt.legend();

# %% [markdown]
# <b> Moving Average </b> <p>
# Calculating  technical indicators used in technical analysis: <br>
# -50 days moving average <br>
# -200 days moving average <br>

# %%
AAPL['MA200'] = AAPL['Adj Close'].rolling(200).mean()

# %%
AAPL.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL'),
#             (    'MA200',     '')],
#            names=['Price', 'Ticker'])

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.876106   75.087502   75.150002   73.797501
# 2020-01-03 00:00:00+00:00   72.167595   74.357498   75.144997   74.125000
# 2020-01-06 00:00:00+00:00   72.742653   74.949997   74.989998   73.187500
# 2020-01-07 00:00:00+00:00   72.400551   74.597504   75.224998   74.370003
# 2020-01-08 00:00:00+00:00   73.565201   75.797501   76.110001   74.290001
# ...                               ...         ...         ...         ...
# 2022-12-30 00:00:00+00:00  128.719330  129.929993  129.949997  127.430000
# 2023-01-03 00:00:00+00:00  123.904617  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.182610  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.855087  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.412231  129.619995  130.289993  124.889999
#
# Price                            Open     Volume       MA200
# Ticker                           AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00   74.059998  135480400         NaN
# 2020-01-03 00:00:00+00:00   74.287498  146322800         NaN
# 2020-01-06 00:00:00+00:00   73.447502  118387200         NaN
# 2020-01-07 00:00:00+00:00   74.959999  108872000         NaN
# 2020-01-08 00:00:00+00:00   74.290001  132079200         NaN
# ...                               ...        ...         ...
# 2022-12-30 00:00:00+00:00  128.410004   77034200  149.850078
# 2023-01-03 00:00:00+00:00  130.279999  112117500  149.677568
# 2023-01-04 00:00:00+00:00  126.889999   89113600  149.494879
# 2023-01-05 00:00:00+00:00  127.129997   80962700  149.298648
# 2023-01-06 00:00:00+00:00  126.010002   87754700  149.108240
#
# [760 rows x 7 columns]

# %%
AAPL[['Adj Close',  'MA200']].plot(label = 'Apple', figsize = (16,8));

# %%
plt.figure(figsize=(16,8))
plt.plot(AAPL['Adj Close'], label="APPLE")

plt.plot(AAPL['MA200'],'r--',label='MA200')
plt.legend()
plt.show()

# %% [markdown]
# <b> Calculation of Bollinger Bands </b>
#
# 1. Middle Band= 20-day simple moving average (SMA)
# 2. Upper Band= 20-day SMA+(20-day standard deviation of price x 2)
# 3. Lower Band= 20-day SMA–(20-day standard deviation of price x 2)
#
# Bollinger Bands illustrate the relative strength or momentum of a stock [2]. BollingerBands act as an envelope around the price of a stock. The bands are more complicated,but they provide more insight than just using the moving average.

# %%
AAPL['middle_band'] = AAPL['Adj Close'].rolling(20).mean()
AAPL['upper_band'] = AAPL['Adj Close'].rolling(20).mean() + AAPL['Adj Close'].rolling(window=20).std()*2
AAPL['lower_band'] = AAPL['Adj Close'].rolling(20).mean() - AAPL['Adj Close'].rolling(window=20).std()*2

# %%
AAPL
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02 00:00:00+00:00   72.876106   75.087502   75.150002   73.797501
# 2020-01-03 00:00:00+00:00   72.167595   74.357498   75.144997   74.125000
# 2020-01-06 00:00:00+00:00   72.742653   74.949997   74.989998   73.187500
# 2020-01-07 00:00:00+00:00   72.400551   74.597504   75.224998   74.370003
# 2020-01-08 00:00:00+00:00   73.565201   75.797501   76.110001   74.290001
# ...                               ...         ...         ...         ...
# 2022-12-30 00:00:00+00:00  128.719330  129.929993  129.949997  127.430000
# 2023-01-03 00:00:00+00:00  123.904617  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.182610  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.855087  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.412231  129.619995  130.289993  124.889999
#
# Price                            Open     Volume       MA200 middle_band  \
# Ticker                           AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00   74.059998  135480400         NaN         NaN
# 2020-01-03 00:00:00+00:00   74.287498  146322800         NaN         NaN
# 2020-01-06 00:00:00+00:00   73.447502  118387200         NaN         NaN
# 2020-01-07 00:00:00+00:00   74.959999  108872000         NaN         NaN
# 2020-01-08 00:00:00+00:00   74.290001  132079200         NaN         NaN
# ...                               ...        ...         ...         ...
# 2022-12-30 00:00:00+00:00  128.410004   77034200  149.850078  136.075163
# 2023-01-03 00:00:00+00:00  130.279999  112117500  149.677568  134.948756
# 2023-01-04 00:00:00+00:00  126.889999   89113600  149.494879  133.944699
# 2023-01-05 00:00:00+00:00  127.129997   80962700  149.298648  133.058534
# 2023-01-06 00:00:00+00:00  126.010002   87754700  149.108240  132.497807
#
# Price                      upper_band  lower_band
# Ticker
# Date
# 2020-01-02 00:00:00+00:00         NaN         NaN
# 2020-01-03 00:00:00+00:00         NaN         NaN
# 2020-01-06 00:00:00+00:00         NaN         NaN
# 2020-01-07 00:00:00+00:00         NaN         NaN
# 2020-01-08 00:00:00+00:00         NaN         NaN
# ...                               ...         ...
# 2022-12-30 00:00:00+00:00  149.384657  122.765668
# 2023-01-03 00:00:00+00:00  148.380020  121.517493
# 2023-01-04 00:00:00+00:00  147.129300  120.760097
# 2023-01-05 00:00:00+00:00  146.463415  119.653653
# 2023-01-06 00:00:00+00:00  145.682244  119.313370
#
# [760 rows x 10 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(AAPL['Adj Close'], label="Close")
plt.plot(AAPL['upper_band'],'g--',label='upper')
plt.plot(AAPL['middle_band'],'r--',label='middle')
plt.plot(AAPL['lower_band'],'y--',label='lower')
plt.legend()
plt.show()

# %% [markdown]
# Zoom in the latest 365 transaction days

# %%
plt.figure(figsize=(16,8))
plt.plot(AAPL['Adj Close'].iloc[-365:], label="Close")
plt.plot(AAPL['upper_band'].iloc[-365:],'g--',label='upper')
plt.plot(AAPL['middle_band'].iloc[-365:],'r--',label='middle')
plt.plot(AAPL['lower_band'].iloc[-365:],'y--',label='lower')
plt.legend()
plt.show()

# %% [markdown]
# <b>Comparison Analysis</b>

# %%
AAPL['Adj Close'].plot(label = 'Apple', figsize = (16,8))
BABA['Adj Close'].plot(label = 'Alibaba')
plt.xlabel("date")
plt.ylabel("$ price")
plt.legend();
